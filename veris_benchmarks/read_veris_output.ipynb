# %%
import numpy as np
import matplotlib.pyplot as plt
import cmocean

# %%
ice, snow, area, uice, vice = np.load('veris_output.npy')

# %%
var = ice[-1]

ind1 = 2
ind2 = 3
cut = var[ind1:-ind2,ind1:-ind2]
plt.pcolormesh(cut, cmap = cmocean.cm.ice)
plt.colorbar()
print(np.min(cut))
np.max(cut)
# Out:
# 0.19660549985899856
# 0.3357930307462722
